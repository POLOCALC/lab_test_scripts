# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
filename = "/home/polocalc/Documents/lab_test_scripts/diode_responsivity/2025_02_17_12_48_15_93GHz/2025_02_17_12_48_15_pwr_stabilization.txt"
t,pwr = np.loadtxt(filename,skiprows=1,unpack=True)

# %%
plt.plot(t,pwr)
